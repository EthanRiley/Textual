# %%
import json

# %%
file = open('stop_words_english.json', encoding='utf8')

# %%
raw = json.load(file)

# %%
raw['stopWords']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5340/2104804570.py in <module>
# ----> 1 raw['stopWords']
#
# TypeError: list indices must be integers or slices, not str

# %%
raw
# Out:
# ['able',
#  'about',
#  'above',
#  'abroad',
#  'according',
#  'accordingly',
#  'across',
#  'actually',
#  'adj',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'ago',
#  'ahead',
#  "ain't",
#  'all',
#  'allow',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'alongside',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'amid',
#  'amidst',
#  'among',
#  'amongst',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anybody',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anyways',
#  'anywhere',
#  'apart',
#  'appear',
#  'appreciate',
#  'appropriate',
#  'are',
#  "aren't",
#  'around',
#  'as',
#  "a's",
#  'aside',
#  'ask',
#  'asking',
#  'associated',
#  'at',
#  'available',
#  'away',
#  'awfully',
#  'back',
#  'backward',
#  'backwards',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'begin',
#  'behind',
#  'being',
#  'believe',
#  'below',
# ...

# %%
file.close()
